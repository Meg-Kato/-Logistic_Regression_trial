# %%
# モジュールのインポート
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from matplotlib.colors import ListedColormap
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')
import random

# %% [markdown]
# ## read csv

# %%
# csvの読み込み
df = pd.read_csv('data.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
# 基本統計量を観察
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# ## visualize data

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# 散布図行列を作成
df_pickup = df.loc[:, ['perimeter_worst', 'concave points_worst', 'radius_worst', 'concave points_mean', 'diagnosis']]
sns.pairplot(df_pickup, size=2.0, hue='diagnosis', markers='+')
plt.show()

# %% [markdown]
# ## set data

# %%
df['diagnosis']=df['diagnosis'].map({'M':1,'B':0})

# %%
# 説明変数と目的変数を指定
X = df.loc[:, ['perimeter_worst', 'concave points_mean']].values
y = df.loc[:, ['diagnosis']].values

# %%
# 型を確認する
print('説明変数:', X[0:5])
print('目的変数:', y[0:5])
# Out:
# 説明変数: [[1.846e+02 1.471e-01]
#  [1.588e+02 7.017e-02]
#  [1.525e+02 1.279e-01]
#  [9.887e+01 1.052e-01]
#  [1.522e+02 1.043e-01]]
# 目的変数: [[1]
#  [1]
#  [1]
#  [1]
#  [1]]

# %%
# scikit-learnの仕様に合わせて､一列のベクトルに変換
y = y.reshape(-1)

# %%
print(y[0:5])
# Out:
# [1 1 1 1 1]

# %%
# データの標準化
scaler = StandardScaler()
scaler.fit(X)
X_std = scaler.transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.3, random_state=0)

# %%
# ロジスティック回帰の実行
lr = LogisticRegression(C=1.0)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
def plot_decision_regions(X, y, classifier, resolution=0.02):
    markers = ("s", "x", "o", "^", "v")
    colors = ("red", "blue", "lightgreen", "gray", "cyan")
    cmap = ListedColormap(colors[:len(np.unique(y))])
    
    x1_min, x1_max = X[:, 0].min()-1 , X[:, 0].max() +1
    x2_min, x2_max = X[:, 1].min()-1 , X[:, 1].max() +1
    
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution), np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
    
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())
    
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1], alpha=0.8, c=cmap(idx),marker=markers[idx], label=cl)

# %%
# 決定境界を出力
plot_decision_regions(X_std, y, lr)
plt.xlabel("perimeter_worst")
plt.ylabel("concave points_mean")
plt.legend(loc = "upper left")
plt.show()

# %%
# 精度の出力
print('train acc: %.3f' % lr.score(X_train, y_train))
print('test acc: %.3f' % lr.score(X_test, y_test))
# Out:
# train acc: 0.930
# test acc: 0.924

# %% [markdown]
# ## test

# %%
breast_cancer_labels = np.array([
    'benign',
    'malignant'
])

# %%
index = np.zeros(50)
for i in range(50):
    index[i] += random.randint(0,X_test.shape[0]-1)
right=0
mistake=0
for i in range(50):
    num = int(index[i])
    pred = lr.predict_proba(X_test[num].reshape(1, -1))
    bestnum  = 0.0
    bestclass = 0
    for n in [0,1]:
        if bestnum < pred[0][n]:
            bestnum = pred[0][n]
            bestclass = n

    if bestclass == y_test[num]:
        print(breast_cancer_labels[bestclass])
        right += 1
    else:
        print(breast_cancer_labels[bestclass] + '≠' + breast_cancer_labels[int(y_test[num])])
        mistake += 1
        
plt.show()
print("The number of correct answers: ", right)
print("The number of mistakes: ", mistake)
print ("A correct answer rate: ", right/(mistake + right) * 100, '%')
# Out:
# benign
# benign
# benign
# malignant
# benign
# malignant≠benign
# malignant
# benign
# benign
# malignant
# benign
# benign
# benign
# benign
# malignant
# benign
# benign
# benign
# benign
# benign
# malignant
# benign
# malignant
# malignant
# malignant≠benign
# malignant
# benign
# benign
# benign
# benign
# benign
# malignant
# malignant
# malignant
# benign
# benign
# benign
# malignant
# benign
# benign
# benign
# benign
# malignant
# benign≠malignant
# benign
# malignant
# benign
# benign
# malignant
# benign
# The number of correct answers:  47
# The number of mistakes:  3
# A correct answer rate:  94.0 %
